# %%
import pandas as pd

# %%
df = pd.read_csv('olx_araraquara_selenium_20260131_193720.csv')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.olx.com.br/imoveis/venda/estado-sp...
# 1     https://www.olx.com.br/imoveis/venda/estado-sp
# 2               https://www.olx.com.br/imoveis/venda
# 3  https://www.olx.com.br/imoveis/venda/estado-sp...
# 4  https://www.olx.com.br/imoveis/venda/estado-sp...
#
#                              titulo  preco tipo_imovel fonte      cidade  \
# 0                   Na minha região    NaN       outro   olx  Araraquara
# 1                     No meu estado    NaN       outro   olx  Araraquara
# 2                    Em todo Brasil    NaN       outro   olx  Araraquara
# 3  DDD 16 - Ribeirão Preto e região    NaN       outro   olx  Araraquara
# 4                        Araraquara    NaN       outro   olx  Araraquara
#
#   estado          data_coleta  quartos bairro localizacao  vagas  area
# 0     SP  2026-01-31 19:36:54      NaN    NaN         NaN    NaN   NaN
# ...
